PTGES
WNT16
IDH3G
VIT32
TP53I3
RP53
MGST1-L1
PIG11
WNT3
TDRD30
ASPP2
CTNNB
BZS
MTS1
IARS1
PICT-1
CCN4
WISP1i
NACC1
WISP-3
L-Myc
NUP53
SARP2
PDRC1
DKK4
MDM35
HTX6
BBP
HMG20B
CT44
PAM
IDH3B
PUR1
PAPA8
SHH
PARK6
bHLHe39
mPGES-1
KRTCAP1
CGI121
PTCH
WNT10B
CCN6
N-CAML1
GAB1
MCC
TP53TG3E
p85
DP2.5
HEL-S-26
CMCU
p532
hWNT5A
GADD34
LCA13
CLG01
C20orf110
WNT14B
TP53TG3A
TP53INP2
WHAMM2
IDP
DKK1
ZF87
CFAP53
BTPS2
MYCBP2
NAC-1
BLES03
NFKB3
REIC
P16INK4A
P53
SDF-5
MMAC1
TP53TG3D
IBRDC2
DP2
p53BP1
PP1294
ARF
TRP53
MDM4
SRFP3
WNT8D
TP53I13
PPP1R13A
WNT5B
GAMOS4
BMND16
C20orf10
JMY
IDH
MYC
PIGU
KET
RP46
CCL28
PIG4
KIAA1549L
BRAF
SDR7C2
SERKAL
SMMCI
BRAF35
P16INK4
MTS-1
MYCT1
BM-011
DRC1
FRP-3
TP53BP2
PHR1
Myc-bp2
MIC5
CCDC11
Phr
ANP-C
L1CAM
PPD1
PDRG1
HSAS
CDK4I
DSCP1
IDH2
Zif87
C11orf41
G2
PPP1R13B
MRT70
NYAP1
C5orf23
Nori-2
TERT
SFRP2
TPTE
MTLC
RRM2B
hTRT
LUN
bHLHe37
WDR79
REPRIMO
FRZB-2
EST2
BTBD30
B(p51A)
p53Lyn
N-myc
KOX11""".splitlines()

# %%
import pickle
d=pickle.load(open('../../methylcapsnet/data/selected_capsules.p','rb'))

# %%
import numpy as np, matplotlib.pyplot as plt

# %%
a=np.array(list(map(len,d['UCSC_RefGene_Name'].values())))

# %%
plt.hist(np.log10(a))
# Out:
# (array([7.490e+02, 1.180e+03, 2.661e+03, 8.497e+03, 6.374e+03, 1.340e+03,
#         3.380e+02, 7.000e+01, 1.500e+01, 3.000e+00]),
#  array([0.        , 0.31136092, 0.62272183, 0.93408275, 1.24544366,
#         1.55680458, 1.86816549, 2.17952641, 2.49088732, 2.80224824,
#         3.11360915]),
#  <a list of 10 Patch objects>)

# %%
np.median(a)
# Out:
# 15.0

# %%
len(np.intersect1d(list(d['UCSC_RefGene_Name'].keys()),gene_list))
# Out:
# 152

# %%
np.intersect1d(list(d['UCSC_RefGene_Name'].keys()),gene_list)
# Out:
# array(['ANO9', 'APC', 'APC2', 'ATRX', 'AVPI1', 'BAIAP2', 'BRAF',
#        'C11orf41', 'C11orf68', 'C11orf95', 'C12orf5', 'C16orf5',
#        'C5orf23', 'C7orf51', 'CCDC11', 'CCL28', 'CDKN2A', 'CRNN',
#        'CTNNB1', 'DAXX', 'DKK1', 'DKK2', 'DKK3', 'DKK4', 'DNMT3A',
#        'DOCK3', 'EI24', 'ENC1', 'FRAT1', 'FRAT2', 'FRZB', 'GAB1', 'GAMT',
#        'GLI1', 'GLTSCR2', 'GPR177', 'H3F3A', 'HERC1', 'HMG20B', 'IARS',
#        'IDH1', 'IDH2', 'IDH3A', 'IDH3B', 'IDH3G', 'IGFBP2', 'JMY',
#        'KCNA1', 'KDM6A', 'KIAA1549', 'KILLIN', 'KLHL35', 'L1CAM', 'LBH',
#        'LITAF', 'LRDD', 'LYN', 'LZTR1', 'MAD1L1', 'MAX', 'MAZ', 'MCC',
#        'MDM4', 'MYC', 'MYCBP', 'MYCBP2', 'MYCBPAP', 'MYCL1', 'MYCN',
#        'MYCT1', 'NACC1', 'NELL1', 'NKD1', 'NKD2', 'NPR3', 'NRP1', 'NUP35',
#        'PAM', 'PDRG1', 'PERP', 'PIGU', 'PINK1', 'PPP1R13B', 'PPP1R15A',
#        'PRODH', 'PRODH2', 'PTCH1', 'PTEN', 'PTGES', 'RAD54L', 'RDH12',
# ...

# %%
len(gene_list)
# Out:
# 644

# %%
np.setdiff1d(gene_list,list(d['UCSC_RefGene_Name'].keys()))
# Out:
# array(['10q23del', '53BP1', '53BP2', 'AEMK', 'AIS', 'AMAP-1', 'AMAP1',
#        'AMY-1', 'ANP-C', 'ANPR-C', 'ANPRC', 'APCL', 'ARF', 'ASPP1',
#        'ASPP2', 'B(p51A)', 'B(p51B)', 'B-RAF1', 'B-raf', 'BAF47', 'BAP2',
#        'BBP', 'BCC7', 'BCNS', 'BEND8', 'BING2', 'BLES03', 'BM-011',
#        'BMFS5', 'BMND16', 'BRAF1', 'BRAF25', 'BRAF35', 'BRPK', 'BTBD14B',
#        'BTBD29', 'BTBD30', 'BTPS2', 'BUD32', 'BZS', 'C11orf69', 'C1orf10',
#        'C1orf139', 'C20orf10', 'C20orf110', 'C20orf126', 'C20orf64',
#        'CAML1', 'CCDS2', 'CCN4', 'CCN5', 'CCN6', 'CD171', 'CDC91L1',
#        'CDIP', 'CDIP1', 'CDK4I', 'CDKN2', 'CFAP53', 'CGI-121', 'CGI121',
#        'CLG01', 'CMCU', 'CMM2', 'CMM9', 'CSS3', 'CT44', 'CT58', 'CTGF-L',
#        'CTNNB', 'CWS1', 'CWS4', 'D2HGA2', 'DAP6', 'DEC', 'DFNB26',
#        'DKCA2', 'DKCB3', 'DKCB4', 'DKK-1', 'DKK-2', 'DKK-4', 'DNMT3A2',
#        'DOR', 'DP2', 'DP2.5', 'DP3', 'DRC1', 'DSCP1', 'EA1', 'EAP1',
# ...
